# %%
import pandas as pd

# %%
dlv=pd.read_csv('Data_Sets/deliveries.csv')

# %%
dlv.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
data=dlv.groupby(['batting_team', 'bowling_team'])['is_super_over']
print(data.sum())
# Out:
# batting_team         bowling_team
# Chennai Super Kings  Deccan Chargers                0
#                      Delhi Capitals                 0
#                      Delhi Daredevils               0
#                      Kings XI Punjab                5
#                      Kochi Tuskers Kerala           0
#                                                    ..
# Sunrisers Hyderabad  Pune Warriors                  0
#                      Rajasthan Royals               0
#                      Rising Pune Supergiant         0
#                      Rising Pune Supergiants        0
#                      Royal Challengers Bangalore    7
# Name: is_super_over, Length: 160, dtype: int64

# %%
data=pd.read_csv('Data_Sets/imdb-top-1000.csv')

# %%
# gen=data.groupby('Series_Title')
gen=data.groupby('Series_Title')

# %%
gen.sum()
# Out:
#                             Released_Year  Runtime      Genre  IMDB_Rating  \
# Series_Title
# (500) Days of Summer                 2009       95     Comedy          7.7
# 12 Angry Men                         1957       96      Crime          9.0
# 12 Years a Slave                     2013      134  Biography          8.1
# 1917                                 2019      119      Drama          8.3
# 2001: A Space Odyssey                1968      149  Adventure          8.3
# ...                                   ...      ...        ...          ...
# Zootopia                             2016      108  Animation          8.0
# Zulu                                 1964      138      Drama          7.7
# Zwartboek                            2006      145      Drama          7.7
# À bout de souffle                    1960       90      Crime          7.8
# Ôkami kodomo no Ame to Yuki          2012      117  Animation          8.1
#
# ...

# %%
gen.min()
# Out:
#                             Released_Year  Runtime      Genre  IMDB_Rating  \
# Series_Title
# (500) Days of Summer                 2009       95     Comedy          7.7
# 12 Angry Men                         1957       96      Crime          9.0
# 12 Years a Slave                     2013      134  Biography          8.1
# 1917                                 2019      119      Drama          8.3
# 2001: A Space Odyssey                1968      149  Adventure          8.3
# ...                                   ...      ...        ...          ...
# Zootopia                             2016      108  Animation          8.0
# Zulu                                 1964      138      Drama          7.7
# Zwartboek                            2006      145      Drama          7.7
# À bout de souffle                    1960       90      Crime          7.8
# Ôkami kodomo no Ame to Yuki          2012      117  Animation          8.1
#
# ...

# %%
gen.mean(numeric_only=True)
# Out:
#                              Runtime  IMDB_Rating  No_of_Votes        Gross  \
# Series_Title
# (500) Days of Summer            95.0          7.7     472242.0   32391374.0
# 12 Angry Men                    96.0          9.0     689845.0    4360000.0
# 12 Years a Slave               134.0          8.1     640533.0   56671993.0
# 1917                           119.0          8.3     425844.0  159227644.0
# 2001: A Space Odyssey          149.0          8.3     603517.0   56954992.0
# ...                              ...          ...          ...          ...
# Zootopia                       108.0          8.0     434143.0  341268248.0
# Zulu                           138.0          7.7      35999.0  790226546.0
# Zwartboek                      145.0          7.7      72643.0    4398392.0
# À bout de souffle               90.0          7.8      73251.0     336705.0
# Ôkami kodomo no Ame to Yuki    117.0          8.1      38803.0  224400323.0
#
#                              Metascore
# ...

# %%
d=gen.sum(numeric_only=True)['Gross'].sort_values(ascending=False).head(3)

# %%
genres=data.groupby('Genre')['IMDB_Rating'].mean(numeric_only=True)

# %%
genres.sort_values(ascending=False).head(3)
# Out:
# Genre
# Western    8.350000
# Crime      8.016822
# Fantasy    8.000000
# Name: IMDB_Rating, dtype: float64

# %%
#  find  the popularuty wich direct the popular 
data
# Out:
#                  Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0    The Shawshank Redemption          1994      142   Drama          9.3
# 1               The Godfather          1972      175   Crime          9.2
# 2             The Dark Knight          2008      152  Action          9.0
# 3      The Godfather: Part II          1974      202   Crime          9.0
# 4                12 Angry Men          1957       96   Crime          9.0
# ..                        ...           ...      ...     ...          ...
# 995    Breakfast at Tiffany's          1961      115  Comedy          7.6
# 996                     Giant          1956      201   Drama          7.6
# 997     From Here to Eternity          1953      118   Drama          7.6
# 998                  Lifeboat          1944       97   Drama          7.6
# 999              The 39 Steps          1935       86   Crime          7.6
#
#                  Director              Star1  No_of_Votes        Gross  \
# ...

# %%
# dtr=directors 
dtr=data.groupby('Director')['No_of_Votes'].sum()

# %%
dtr.sort_values(ascending=False).head(1)
# Out:
# Director
# Christopher Nolan    11578345
# Name: No_of_Votes, dtype: int64

# %%
data.describe()
# Out:
#            Runtime  IMDB_Rating   No_of_Votes         Gross   Metascore
# count  1000.000000  1000.000000  1.000000e+03  1.000000e+03  843.000000
# mean    122.891000     7.949300  2.736929e+05  1.282781e+08   77.971530
# std      28.093671     0.275491  3.273727e+05  2.011110e+08   12.376099
# min      45.000000     7.600000  2.508800e+04  1.305000e+03   28.000000
# 25%     103.000000     7.700000  5.552625e+04  5.012919e+06   70.000000
# 50%     119.000000     7.900000  1.385485e+05  3.953432e+07   79.000000
# 75%     137.000000     8.100000  3.741612e+05  1.615997e+08   87.000000
# max     321.000000     9.300000  2.343110e+06  9.366622e+08  100.000000

# %%
#  agg fn very powerfull fn 
aggdata=data.groupby('Genre')

# %%
dicagg=aggdata.agg(
    {
        'Runtime':'mean',
        'IMDB_Rating':'mean',
        'No_of_Votes':'sum',
        'Gross':'sum',
        'Metascore':'min'
    }
)

# %%
dicagg
# Out:
#               Runtime  IMDB_Rating  No_of_Votes         Gross  Metascore
# Genre
# Action     129.046512     7.949419     72282412  3.263226e+10       33.0
# Adventure  134.111111     7.937500     22576163  9.496922e+09       41.0
# Animation   99.585366     7.930488     21978630  1.463147e+10       61.0
# Biography  136.022727     7.938636     24006844  8.276358e+09       48.0
# Comedy     112.129032     7.901290     27620327  1.566387e+10       45.0
# Crime      126.392523     8.016822     33533615  8.452632e+09       47.0
# Drama      124.737024     7.957439     61367304  3.540997e+10       28.0
# Family     107.500000     7.800000       551221  4.391106e+08       67.0
# Fantasy     85.000000     8.000000       146222  7.827267e+08        NaN
# Film-Noir  104.000000     7.966667       367215  1.259105e+08       94.0
# Horror     102.090909     7.909091      3742556  1.034649e+09       46.0
# Mystery    119.083333     7.975000      4203004  1.256417e+09       52.0
# ...

# %%
#  using list  gpby multiple  aggrigate fn applay on 1 clm 
listagg = aggdata.agg(['min','max','sum'])

# %%
#  comnbine the min list and dict 
CLD=aggdata.agg({
      'Runtime':['min','max','mean'],
      'IMDB_Rating':['min','sum','max'],
      'No_of_Votes':'sum',
      'Gross':['mean','max']
       
})

# %%
data
# Out:
#                  Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0    The Shawshank Redemption          1994      142   Drama          9.3
# 1               The Godfather          1972      175   Crime          9.2
# 2             The Dark Knight          2008      152  Action          9.0
# 3      The Godfather: Part II          1974      202   Crime          9.0
# 4                12 Angry Men          1957       96   Crime          9.0
# ..                        ...           ...      ...     ...          ...
# 995    Breakfast at Tiffany's          1961      115  Comedy          7.6
# 996                     Giant          1956      201   Drama          7.6
# 997     From Here to Eternity          1953      118   Drama          7.6
# 998                  Lifeboat          1944       97   Drama          7.6
# 999              The 39 Steps          1935       86   Crime          7.6
#
#                  Director              Star1  No_of_Votes        Gross  \
# ...

# %%
# find number of movies starting with A for each group

def foo(group):
  return group['Series_Title'].str.startswith('A').sum()
aggdata.apply(foo)
# Out:
# C:\Users\rm948\AppData\Local\Temp\ipykernel_1808\1240046270.py:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   aggdata.apply(foo)
# Genre
# Action       10
# Adventure     2
# Animation     2
# Biography     9
# Comedy       14
# Crime         4
# Drama        21
# Family        0
# Fantasy       0
# Film-Noir     0
# Horror        1
# Mystery       0
# Thriller      0
# Western       0
# dtype: int64

# %%
# find ranking of each movie in the group according to IMDB score

def rank_movie(data):
  data['genre_rank'] = data['IMDB_Rating'].rank(ascending=False)
  return data

# %%
aggdata.apply(movie_rank,include_groups=False)
# Out:
# Genre
# Action    2      172.0
#           5      171.0
#           8      169.5
#           10     169.5
#           13     167.0
#                  ...
# Thriller  700      1.0
# Western   12       4.0
#           48       3.0
#           115      2.0
#           691      1.0
# Name: IMDB_Rating, Length: 1000, dtype: float64

# %%
six=dlv[dlv['batsman_runs']==6]

# %%
six.groupby('batsman')['batsman'].sum()
# Out:
# batsman
# A Ashish Reddy     A Ashish ReddyA Ashish ReddyA Ashish ReddyA As...
# A Choudhary                                              A Choudhary
# A Flintoff                                      A FlintoffA Flintoff
# A Hales                   A HalesA HalesA HalesA HalesA HalesA Hales
# A Mishra                    A MishraA MishraA MishraA MishraA Mishra
#                                          ...
# Y Venugopal Rao    Y Venugopal RaoY Venugopal RaoY Venugopal RaoY...
# YK Pathan          YK PathanYK PathanYK PathanYK PathanYK PathanY...
# YV Takawale                        YV TakawaleYV TakawaleYV Takawale
# Yuvraj Singh       Yuvraj SinghYuvraj SinghYuvraj SinghYuvraj Sin...
# Z Khan                                                  Z KhanZ Khan
# Name: batsman, Length: 336, dtype: object

# %%
#  find the name of the batsman are last 5 over me 4,6 mare ho 
bt=dlv[dlv]

# %%
data=dlv[(dlv['over']>=16) & (dlv['batsman_runs']==4) | (dlv['batsman_runs']==6) ]

# %%
addclm=data.groupby('batsman')['batsman_runs'].count().sort_values(ascending=False)

# %%
addclm = data.groupby('batsman')['batsman_runs'].sum().sort_values(ascending=False)
data['last 5 overs batsman'] = data['batsman'].map(addclm)
# Out:
# C:\Users\rm948\AppData\Local\Temp\ipykernel_1808\1018999207.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['last 5 overs batsman'] = data['batsman'].map(addclm)

# %%
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 10             1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 47             1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 75             1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 89             1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 91             1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179052     11415       2  Chennai Super Kings               Mumbai Indians
# 179061     11415       2  Chennai Super Kings               Mumbai Indians
# 179062     11415       2  Chennai Super Kings               Mumbai Indians
# 179063     11415       2  Chennai Super Kings               Mumbai Indians
# 179071     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
#  find the run all matches of the Vk 
s_dhawan=dlv[dlv['batsman']=='S Dhawan']
s_dhawan.groupby('bowling_team')['batsman_runs'].sum().reset_index()
# Out:
#                    bowling_team  batsman_runs
# 0           Chennai Super Kings           651
# 1               Deccan Chargers           118
# 2              Delhi Daredevils           525
# 3                 Gujarat Lions           127
# 4               Kings XI Punjab           638
# 5          Kochi Tuskers Kerala             4
# 6         Kolkata Knight Riders           660
# 7                Mumbai Indians           673
# 8                 Pune Warriors            81
# 9              Rajasthan Royals           496
# 10       Rising Pune Supergiant            49
# 11      Rising Pune Supergiants            89
# 12  Royal Challengers Bangalore           483
# 13          Sunrisers Hyderabad            38

# %%
#  crete a fn to find the fighest score of the batsman
dlv
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
def maxscoure(btname):
    sd=dlv[dlv['batsman']==btname]
    return  sd.groupby('batsman')['batsman_runs'].sum().sort_values(ascending=False).head(1)

# %%
maxscoure('RA Jadeja')
# Out:
# batsman
# RA Jadeja    1951
# Name: batsman_runs, dtype: int64
