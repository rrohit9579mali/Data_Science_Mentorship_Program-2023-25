# %% [markdown]
# #  list in padas to create a  Series

# %%
import numpy as np
import pandas as pd

# %%
#  create a 1st series  with county name 
country =['india','us','dubai','astrolia','Japan ','shrilanka']
cn=pd.Series(country) # with index coountry name print 
cn
# Out:
# 0        india
# 1           us
# 2        dubai
# 3     astrolia
# 4       Japan
# 5    shrilanka
# dtype: object

# %%
#  create a integer onbject 
marks=[12,45,63,89,75,52,68]
pd.Series(marks)
# Out:
# 0    12
# 1    45
# 2    63
# 3    89
# 4    75
# 5    52
# 6    68
# dtype: int64

# %%
#  create a subjcet and replace the index of the pd Series with subject name 
subject=['math','bio','Java ','mern stack','data science','ml','english']
data=pd.Series(marks,index=subject) 
print("data\n",data)
# Out:
# data
#  math            12
# bio             45
# Java            63
# mern stack      89
# data science    75
# ml              52
# english         68
# dtype: int64

# %% [markdown]
# #  Series by using dict

# %%
marks={
    'math':50,
    'e':30,
    'b':20,
    'd':50
}
marks=pd.Series(marks,name='rohit ka marks ')
marks
# Out:
# math    50
# e       30
# b       20
# d       50
# Name: rohit ka marks , dtype: int64

# %% [markdown]
# #  Series Stributes

# %%
#  size \
# total number of items in Series 
marks.size
# Out:
# 4

# %%
#  index 
#  find the idx of the Series items

marks.index
# Out:
# Index(['math', 'e', 'b', 'd'], dtype='object')

# %%
#  value 
#  to get a all value in Series array 

marks.values
# Out:
# array([50, 30, 20, 50])

# %%
#  is_unique  element in Series array 

marks.is_unique
# Out:
# False

# %%
#  name 
marks.name
# Out:
# 'rohit ka marks '

# %%
#  method in series
subscribers_data = pd.read_csv('DtataSets_16/subs.xlsx')  # Check if path is correct
subscribers_data = subscribers_data.squeeze()  # Use .squeeze() separately if needed
print(subscribers_data)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[16], line 2
#       1 #  method in series
# ----> 2 subscribers_data = pd.read_csv('DtataSets_16/subs.xlsx')  # Check if path is correct
#       3 subscribers_data = subscribers_data.squeeze()  # Use .squeeze() separately if needed
#       4 print(subscribers_data)
#
# ...

# %%
#  import the all data of the kolih each ipl run 

vk=pd.read_csv('DtataSets_16/kohli_ipl.csv',index_col='match_no')
vk.squeeze()
print(vk)
# Out:
#           runs
# match_no
# 1            1
# 2           23
# 3           13
# 4           12
# 5            1
# ...        ...
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7
#
# [215 rows x 1 columns]

# %%
#  movies 
movies=pd.read_csv('DtataSets_16/bollywood.csv',index_col='movie')
movies.squeeze()
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# #  head and tail methos

# %%
#  head meathod 1st 5 row data dete 
# eg 
h=vk.head()
t=vk.tail()
print("1st 5 row : ",h)
print("last 5 rows ",t)
# Out:
# 1st 5 row :            runs
# match_no
# 1            1
# 2           23
# 3           13
# 4           12
# 5            1
# last 5 rows            runs
# match_no
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7

# %%
#  print the number of head and tail 
h=vk.head(12)
t=vk.tail(20)

print("1st 5 row : ",h)
print("last 5 rows ",t)
# Out:
# 1st 5 row :            runs
# match_no
# 1            1
# 2           23
# 3           13
# 4           12
# 5            1
# 6            9
# 7           34
# 8            0
# 9           21
# 10           3
# 11          10
# 12          38
# last 5 rows            runs
# match_no
# 196         25
# 197         51
# 198         53
# 199         39
# 200         41
# 201         12
# 202          5
# 203         48
# 204          1
# 205         12
# 206          0
# 207          0
# 208          9
# 209         58
# 210         30
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7

# %% [markdown]
# #  sample methops in series

# %%
#  to genarate the random row and give  the data 

s=vk.sample()
m=movies.sample()
print(s)
print(m)
# Out:
#           runs
# match_no
# 45          67
#                                 lead
# movie
# I Proud to Be an Indian  Sohail Khan

# %%
#  value_counts()
movies.value_counts()
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Zara Sheikh          1
# Zareen Khan          1
# Ganesh Acharya       1
# Garima Agarwal       1
# Aanchal Dwivedi      1
# Name: count, Length: 566, dtype: int64

# %%
#  sort the data 
m=vk.squeeze()
largest=m.sort_values(ascending=False).head(1).values[0]
print(largest)
# Out:
# 113

# %%
#  sort index perrhenate 

movies.sort_index(inplace=True)
movies
#  movie sorted permenetly
# Out:
#                                         lead
# movie
# 1920 (film)                 Rajniesh Duggall
# 1920: London                   Sharman Joshi
# 1920: The Evil Returns           Vicky Ahuja
# 1971 (2007 film)              Manoj Bajpayee
# 2 States (2014 film)            Arjun Kapoor
# ...                                      ...
# Zindagi 50-50                    Veena Malik
# Zindagi Na Milegi Dobara      Hrithik Roshan
# Zindagi Tere Naam         Mithun Chakraborty
# Zokkomon                     Darsheel Safary
# Zor Lagaa Ke...Haiya!          Meghan Jadhav
#
# [1500 rows x 1 columns]

# %%
movies
# Out:
#                                         lead
# movie
# 1920 (film)                 Rajniesh Duggall
# 1920: London                   Sharman Joshi
# 1920: The Evil Returns           Vicky Ahuja
# 1971 (2007 film)              Manoj Bajpayee
# 2 States (2014 film)            Arjun Kapoor
# ...                                      ...
# Zindagi 50-50                    Veena Malik
# Zindagi Na Milegi Dobara      Hrithik Roshan
# Zindagi Tere Naam         Mithun Chakraborty
# Zokkomon                     Darsheel Safary
# Zor Lagaa Ke...Haiya!          Meghan Jadhav
#
# [1500 rows x 1 columns]

# %% [markdown]
# #  matahamatical method's

# %%
# sum of the all value 
vk.sum()
# Out:
# runs    6634
# dtype: int64

# %%
#  product 
vk.product()
# Out:
# runs    0
# dtype: int64

# %%
#  counte the number of value present in a data 
vk.count()
# Out:
# runs    215
# dtype: int64

# %%
movies.count()
# Out:
# lead    1500
# dtype: int64

# %%
# subscribers_data.count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 subscribers_data.count()
#
# NameError: name 'subscribers_data' is not defined

# %%
#  dealy use fn in math 
print(vk.mean())
print(vk.mod(255))
print(vk.median())
print(vk.std())
print(vk.var())
# Out:
# runs    30.855814
# dtype: float64
#           runs
# match_no
# 1            1
# 2           23
# 3           13
# 4           12
# 5            1
# ...        ...
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7
#
# [215 rows x 1 columns]
# runs    24.0
# dtype: float64
# runs    26.229801
# dtype: float64
# runs    688.002478
# dtype: float64

# %%
# maximum value in data 
print(vk.max())
print(vk.min())
# Out:
# runs    113
# dtype: int64
# runs    0
# dtype: int64

# %%
movies.max()
# Out:
# lead    Zulfi Sayed
# dtype: object

# %%
print(len(vk))
print(len(movies))
# Out:
# 215
# 1500

# %%
print(sorted(movies))
# Out:
# ['lead']

# %%
movies
print(max(vk))
# Out:
# runs

# %%
100-vk
# Out:
#           runs
# match_no
# 1           99
# 2           77
# 3           87
# 4           88
# 5           99
# ...        ...
# 211        100
# 212         80
# 213         27
# 214         75
# 215         93
#
# [215 rows x 1 columns]

# %%
#  famous top 20 movies
m=vk[vk>=50].count
m
# Out:
# <bound method DataFrame.count of           runs
# match_no
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# ...        ...
# 211        NaN
# 212        NaN
# 213       73.0
# 214        NaN
# 215        NaN
#
# [215 rows x 1 columns]>

# %%
vk.plot()
# Out:
# <Axes: xlabel='match_no'>

# %%
movies.value_counts().head(20).plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
movies.value_counts().tail(20).plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
vk.squeeze()
vk[vk>=100].plot(kind='pie',subplots=True)
# Out:
# array([<Axes: ylabel='runs'>], dtype=object)
