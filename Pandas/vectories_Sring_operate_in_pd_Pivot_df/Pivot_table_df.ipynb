# %%
import pandas as pd
import numpy as np 
import seaborn as sns

# %%
df=sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
bill=df.groupby('sex')[['total_bill']].mean()
# Out:
# C:\Users\rm948\AppData\Local\Temp\ipykernel_14944\2859718947.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   bill=df.groupby('sex')[['total_bill']].mean()

# %%
df.groupby(['sex','smoker'])[['total_bill']].mean()
# Out:
# C:\Users\rm948\AppData\Local\Temp\ipykernel_14944\1859643203.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['sex','smoker'])[['total_bill']].mean()
#                total_bill
# sex    smoker
# Male   Yes      22.284500
#        No       19.791237
# Female Yes      17.977879
#        No       18.105185

# %%
#  how to cate a pivot_table withou specifing values
df.pivot_table(index='sex', columns='smoker', values='total_bill', aggfunc='mean',observed=True)
# Out:
# smoker        Yes         No
# sex
# Male    22.284500  19.791237
# Female  17.977879  18.105185

# %%
# 3d data set create and bass the multiple clm as index aor clms or values 
df.pivot_table(index=['sex','smoker'],columns=['day','time'],values=['total_bill'],observed=False)
# Out:
#               total_bill
# day                 Thur               Fri                Sat        Sun
# time               Lunch Dinner      Lunch  Dinner     Dinner     Dinner
# sex    smoker
# Male   Yes     19.171000    NaN  11.386667  25.892  21.837778  26.141333
#        No      18.486500    NaN        NaN  17.475  19.929063  20.403256
# Female Yes     19.218571    NaN  13.260000  12.200  20.266667  16.540000
#        No      15.899167  18.78  15.980000  22.750  19.003846  20.824286

# %%
data=pd.read_csv('Data_Sets_pivot+table/expense_data.csv')

# %%
data.head()
# Out:
#              Date               Account        Category  Subcategory  \
# 0  3/2/2022 10:11  CUB - online payment            Food          NaN
# 1  3/2/2022 10:11  CUB - online payment           Other          NaN
# 2  3/1/2022 19:50  CUB - online payment            Food          NaN
# 3  3/1/2022 18:56  CUB - online payment  Transportation          NaN
# 4  3/1/2022 18:22  CUB - online payment            Food          NaN
#
#                Note    INR Income/Expense  Note.1  Amount Currency  Account.1
# 0           Brownie   50.0        Expense     NaN    50.0      INR       50.0
# 1  To lended people  300.0        Expense     NaN   300.0      INR      300.0
# 2            Dinner   78.0        Expense     NaN    78.0      INR       78.0
# 3             Metro   30.0        Expense     NaN    30.0      INR       30.0
# 4            Snacks   67.0        Expense     NaN    67.0      INR       67.0

# %%
#  plot the graph month by month based on the Category and  amount 
data.set_index('Date')
# Out:
#                                Account        Category  Subcategory  \
# Date
# 3/2/2022 10:11    CUB - online payment            Food          NaN
# 3/2/2022 10:11    CUB - online payment           Other          NaN
# 3/1/2022 19:50    CUB - online payment            Food          NaN
# 3/1/2022 18:56    CUB - online payment  Transportation          NaN
# 3/1/2022 18:22    CUB - online payment            Food          NaN
# ...                                ...             ...          ...
# 11/22/2021 14:16  CUB - online payment            Food          NaN
# 11/22/2021 14:16  CUB - online payment            Food          NaN
# 11/21/2021 17:07  CUB - online payment  Transportation          NaN
# 11/21/2021 15:50  CUB - online payment            Food          NaN
# 11/21/2021 13:30  CUB - online payment           Other          NaN
#
#                                 Note     INR Income/Expense  Note.1  Amount  \
# Date
# ...

# %%
#  to conver the date in date time  and fetch the month 
data['Date']=pd.to_datetime(data['Date'])

# %%
data['month']=data['Date'].dt.month_name()

# %%
x=data.pivot_table(index='month',columns='Category',values='INR')

# %%
# how to plot the graph 
df.pivot_table(index='sex', columns='smoker', values='total_bill', aggfunc='sum',margins=True,observed=True)
# Out:
# smoker      Yes       No      All
# sex
# Male    1337.07  1919.75  3256.82
# Female   593.27   977.68  1570.95
# All     1930.34  2897.43  4827.77

# %%
# df[df['sex']=="Female"]=np.nan
df.pivot_table(index='sex',columns='smoker',values='total_bill',aggfunc='sum',observed=True,fill_value=2)
# Out:
# smoker      Yes       No
# sex
# Male    1337.07  1919.75
# Female   593.27   977.68

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
