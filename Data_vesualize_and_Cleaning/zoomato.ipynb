# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
z_df=pd.read_csv('zumato_data_sets/zomato_restaurants.csv')

# %%
# Out:
#      Unnamed: 0 Restaurant ID Restaurant Name Country Name  Country Code  \
# 2481       2480         35217    Joey's Pizza        India           1.0
# 2482       2481      18447068      Cafe Hydro        India           1.0
# 2498       2497      18318116         R' ADDA        India           1.0
#
#         City                                            Address  \
# 2481  Mumbai  6 & 7, Upvan Building, Near Indian Oil Colony,...
# 2482  Mumbai  Esspee Tower, Rajendra Nagar, Dattapada Road, ...
# 2498  Mumbai  Ramee Guestline Hotel, 462, A B Nair Road, Juh...
#
#                          Locality                     Locality Verbose  \
# 2481                   Azad Nagar                   Azad Nagar, Mumbai
# 2482                Borivali East                Borivali East, Mumbai
# 2498  Ramee Guestline Hotel, Juhu  Ramee Guestline Hotel, Juhu, Mumbai
#
#         Longitude  ...            Currency Has Table booking  \
# 2481    72.829976  ...  Indian Rupees(Rs.)                No
# ...
